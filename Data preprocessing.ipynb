# %%
import pandas as pd
df = pd.read_csv("radiology_data.csv")

# Inspect the data
print(df.shape)
print(df.info())
print(df.head())
# Out:
# (3419, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3419 entries, 0 to 3418
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   findings    3419 non-null   object
#  1   impression  3419 non-null   object
# dtypes: object(2)
# memory usage: 53.6+ KB
# None
#                                             findings  \
# 0  The cardiac silhouette and mediastinum size ar...
# 1  The cardiomediastinal silhouette is within nor...
# 2  Both lungs are clear and expanded. Heart and m...
# 3  There is XXXX increased opacity within the rig...
# 4  Interstitial markings are diffusely prominent ...
#
#                                           impression
# 0                               Normal chest x-XXXX.
# 1                  No acute cardiopulmonary process.
# 2                                 No active disease.
# 3  1. Increased opacity in the right upper lobe w...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(707)

# %%
df = df.drop_duplicates()

# %%
df.to_csv("radiology_data_No_duplicate.csv", index=False)
